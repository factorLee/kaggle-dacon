# %%
# !mkdir data

# %%
# !cp "/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/train.csv"
# !cp "/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/test.csv"
# !cp "/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/sample_submission.csv"
# Out:
# cp: missing destination file operand after '/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/train.csv'
# Try 'cp --help' for more information.
# cp: missing destination file operand after '/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/test.csv'
# Try 'cp --help' for more information.
# cp: missing destination file operand after '/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/sample_submission.csv'
# Try 'cp --help' for more information.

# %%
import pandas as pd

# %%
train = pd.read_csv("/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/train.csv")
test = pd.read_csv("/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/test.csv")
sample_submission = pd.read_csv("/content/drive/MyDrive/데이콘/[연습]신용카드 사용자 연체 예측 AI 경진대회/data/open 2/sample_submission.csv")

# %%
train.shape
# Out:
# (26457, 20)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
# ...

# %%
train.tail()
# Out:
#        index gender car reality  child_num  income_total    income_type  \
# 26452  26452      F   N       N          2      225000.0  State servant
# 26453  26453      F   N       Y          1      180000.0        Working
# 26454  26454      F   Y       N          0      292500.0        Working
# 26455  26455      M   N       Y          0      171000.0        Working
# 26456  26456      F   N       N          0       81000.0        Working
#
#                             edu_type           family_type         house_type  \
# 26452  Secondary / secondary special               Married  House / apartment
# 26453               Higher education             Separated  House / apartment
# 26454  Secondary / secondary special        Civil marriage       With parents
# 26455              Incomplete higher  Single / not married  House / apartment
# 26456  Secondary / secondary special        Civil marriage  House / apartment
#
# ...

# %%
train.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       8171
# family_size         0
# begin_month         0
# credit              0
# dtype: int64

# %%
train = train.drop("occyp_type", axis=1)
test = test.drop("occyp_type", axis=1)

# %%
test.isnull().sum(), train.isnull().sum()
# Out:
# (index            0
#  gender           0
#  car              0
#  reality          0
#  child_num        0
#  income_total     0
#  income_type      0
#  edu_type         0
#  family_type      0
#  house_type       0
#  DAYS_BIRTH       0
#  DAYS_EMPLOYED    0
#  FLAG_MOBIL       0
#  work_phone       0
#  phone            0
#  email            0
#  family_size      0
#  begin_month      0
#  dtype: int64, index            0
#  gender           0
#  car              0
#  reality          0
#  child_num        0
#  income_total     0
#  income_type      0
#  edu_type         0
#  family_type      0
#  house_type       0
#  DAYS_BIRTH       0
#  DAYS_EMPLOYED    0
#  FLAG_MOBIL       0
#  work_phone       0
#  phone            0
#  email            0
#  family_size      0
#  begin_month      0
#  credit           0
#  dtype: int64)

# %%
len(train['gender'].unique())
# Out:
# 2

# %%
unique_len = train.apply(lambda x: len(x.unique()))
unique_len
# Out:
# index            26457
# gender               2
# car                  2
# reality              2
# child_num            9
# income_total       249
# income_type          5
# edu_type             5
# family_type          5
# house_type           6
# DAYS_BIRTH        6621
# DAYS_EMPLOYED     3470
# FLAG_MOBIL           1
# work_phone           2
# phone                2
# email                2
# family_size         10
# begin_month         61
# credit               3
# dtype: int64

# %% [markdown]
# 1. 2개 이하
# 2. 2개 초과 10개 이하
# 3. 10개 초과

# %%
group_1 = unique_len[unique_len <= 2].index
group_1
# Out:
# Index(['gender', 'car', 'reality', 'FLAG_MOBIL', 'work_phone', 'phone',
#        'email'],
#       dtype='object')

# %%
group_2 = unique_len[(unique_len)]
